# %% [markdown]
# **Hello Salam!**
#
# Nice to meet you! My name is Alex, and I will review your **How to Tell a Story Using Data** project. Nice to meet you again! I've added all my comments on your project to cells with different coloring. Please, do not move or delete them - it helps us move faster:
#
# <div class="alert alert-success">
# <b>Reviewer's comment v.1</b>
#
# 👍 I am using green color for my comment if everything is done successfully.
# </div>
#
# <div class="alert alert-warning">
# <b>Reviewer's comment v.1</b>
#
# 📝 I will use yellow color for my comment if I can give you a recommendation or think that something can be improved. These are optional recommendations, but it will be perfect if you work with them in this or future projects.
# </div>
#
# <div class="alert alert-danger">
# <b>Reviewer's comment v.1</b>
#
# ✍ I am using red color for my comment if the block requires some extra work or corrections. The project couldn’t be accepted with red comments.
# </div>
#
# To make a dialog, let’s use this style for your remarks:
# <div class="alert alert-info">
# <b>Student's comment v.1</b>
#
# Just like this. To make a similar block - double click on the block, copy and edit it in places you are changing. Also, if you have any questions, you could highlight them using this block.
# </div>
#
# Now, let’s go to data analysis!
#
# ---
#
# <div class="alert alert-success">
# <b>General feedback v.1</b>
#
# 👋 Salam, thank you for sending the project 👍
#
# ⭐ You have done a very good job. I am really impressed with your project. You demonstrate confident knowledge and skills. You are great at using different libraries for data visualization and different types of graphs. The main results were correct. You can start your presentation.
#
# ✍ <span class="text-danger"> However, in one task it is necessary to provide more extended conclusions on the results obtained. Please see my additional comments.</span>
#
# 📝 Keep up the good work, and come back soon!
#
#
# <br>
# Best regards,
# <br> Alex
# </div>
#
# ---

# %% [markdown]
# To make a dialog, let’s use this style for your remarks:
# <div class="alert alert-info">
# <b>Student's comment v.1</b>
#
# Hi Alex. I'm so greatfull for your time that you gave reviewing my project. I'm also happy by your recommendations, that I'm happy to apply, also your notes (your way, words made me feeling relaxe, cofortable to fix my codes easlly) THANK YOU SO MUCH
# </div>
#
#
# ---
#
# <div class="alert alert-success">
# <b>General feedback v.2</b>
#
# 👋 Salam, thank you for your additioanl job with project and your feedback on my comment 👍 You have done a very good job. There are no more questions about the project itself. Thank you for correcting some charts and additional findings.
#
# ✍ <span class="text-danger"> However, I have some comments about the presentation that need to be taken into account in the new version.</span> Please see them at the end of the notebook.
#
# 📝 I hope you will not have difficulty with the presentation and it will be a positive experience for you.
#
#
# <br>
# Best regards,
# <br> Alex
# </div>
#
# ---

# %% [markdown]
# To make a dialog, let’s use this style for your remarks:
# <div class="alert alert-info">
# <b>Student's comment v.1</b>
#
# Hi again, I learned from the 6th project a lot of things, coz it returned to me so many times! very step helps us in our future career that I can't wait to start :)
# </div>
#
# ---
#
# <div class="alert alert-success">
# <b>General feedback v.3</b>
#
# 👋 Salam, thanks for updating the slides. Now everything is correct! Congratulations, the project can be accepted! It was a pleasure to review your project!
#
# PS I guess that six project is the most difficult one on the course.
#
#
# <br>
# Best regards,
# <br> Alex
# </div>
#
# ---

# %% [markdown]
# # Robot-Run Cafe in Los Angeles.

# %% [markdown]
# # Project description
# You’ve decided to open a small robot-run cafe in Los Angeles. The project is promising but expensive, so you and your partners decide to try to attract investors. They’re interested in the current market conditions—will you be able to maintain your success when the novelty of robot waiters wears off?

# %% [markdown]
# # Data description
# rest_data table:
#
# object_name — establishment name
# chain — chain establishment (TRUE/FALSE)
# object_type — establishment type
# address — address
# number — number of seats

# %% [markdown]
# The steps:

# %% [markdown]
# -Investigate the proportions of the various types of establishments. Plot a graph.
#
# -Investigate the proportions of chain and nonchain establishments. Plot a graph.
#
# -Which type of establishment is typically a chain?
#
# -What characterizes chains.
#
# -Determine the average number of seats for each type of restaurant.
#
# -Put the data on street names from the address column in a separate column.
#
# -Plot a graph of the top ten streets by number of restaurants.
#
# -Find the number of streets that only have one restaurant.
#
# -The distribution of the number of seats. What trends can you see?
#
# -Overall conclusion and provide recommendations on restaurant type and number of seats.
#
# -Preparing a presentation

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# 👍 Good start with the project and data description. Here we could add the description of the main project steps (or table of contents).
#
# </div>

# %% [markdown]
# # Download the data and prepare it for analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import datetime as dt
import numpy as np
import plotly.graph_objects as go
# !pip install usaddress
import usaddress
# Out:
# ...
#      |████████████████████████████████| 63 kB 5.5 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 1.0 MB 45.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 829 kB 58.9 MB/s eta 0:00:01
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=c00b005c83a3e331d8a6405d5d9cee9104cf904ef15d99ff332f6064f4cf69d6
#   Stored in directory: /home/jovyan/.cache/pip/wheels/2f/a0/d3/4030d9f80e6b3be787f19fc911b8e7aa462986a40ab1e4bb94
# Successfully built future
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# 👍 Correct! It's a good practice to make all imports in 1st cell! That is in line with [PEP 8 -- Style Guide for Python Code](https://www.python.org/dev/peps/pep-0008/)
# </div>

# %%
rest = pd.read_csv('/datasets/rest_data_us.csv')

# %%
rest.head()
# Out:
#       id          object_name                    address  chain object_type  \
# 0  11786  HABITAT COFFEE SHOP     3708 N EAGLE ROCK BLVD  False        Cafe
# 1  11787             REILLY'S        100 WORLD WAY # 120  False  Restaurant
# 2  11788       STREET CHURROS  6801 HOLLYWOOD BLVD # 253  False   Fast Food
# 3  11789    TRINITI ECHO PARK         1814 W SUNSET BLVD  False  Restaurant
# 4  11790               POLLEN         2100 ECHO PARK AVE  False  Restaurant
#
#    number
# 0      26
# 1       9
# 2      20
# 3      22
# 4      20

# %% [markdown]
# <div class="alert alert-warning">
# <b>Reviewer's comment v.1</b>
#
# 💡 As a recommendation: please, pay attention to data frame formatting in your project. Don't forget to use `head()`, `tail()`, or `sample()` when outputting large tables. If you leave everything "as is", when you save the project to `GitHub`, all the tables will expand to their full length and take up most of the project.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.2</b>
#
# 👍 Thank you for considering this point.
# </div>

# %%
rest.describe()
# Out:
#                  id       number
# count   9651.000000  9651.000000
# mean   16611.000000    43.695161
# std     2786.148058    47.622874
# min    11786.000000     1.000000
# 25%    14198.500000    14.000000
# 50%    16611.000000    27.000000
# 75%    19023.500000    46.000000
# max    21436.000000   229.000000

# %%
rest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9651 entries, 0 to 9650
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9651 non-null   int64
#  1   object_name  9651 non-null   object
#  2   address      9651 non-null   object
#  3   chain        9648 non-null   object
#  4   object_type  9651 non-null   object
#  5   number       9651 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 452.5+ KB

# %%
rest['chain'] = rest['chain'].astype('boolean')

# %%
rest['object_type'] = rest['object_type'].astype('category')

# %%
rest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9651 entries, 0 to 9650
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9651 non-null   int64
#  1   object_name  9651 non-null   object
#  2   address      9651 non-null   object
#  3   chain        9648 non-null   boolean
#  4   object_type  9651 non-null   category
#  5   number       9651 non-null   int64
# dtypes: boolean(1), category(1), int64(2), object(2)
# memory usage: 330.2+ KB

# %%
rest['chain'].isnull().sum()
# Out:
# 3

# %%
rest.duplicated().sum()
# Out:
# 0

# %%
restd = rest[['object_name','address']]
restd.duplicated().sum()
# Out:
# 0

# %%
null_chain = pd.isnull(rest["chain"]) 
    
rest[null_chain]
# Out:
#          id              object_name               address  chain object_type  \
# 7408  19194  TAQUERIA LOS 3 CARNALES  5000 E WHITTIER BLVD   <NA>  Restaurant
# 7523  19309     JAMMIN JIMMY'S PIZZA   1641 FIRESTONE BLVD   <NA>       Pizza
# 8648  20434    THE LEXINGTON THEATER          129 E 3RD ST   <NA>  Restaurant
#
#       number
# 7408      14
# 7523       1
# 8648      35

# %%
rest = rest.dropna()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# 👍 Good job here! The data have been loaded and observed. The amount of missing values is not so large that we can omit them.
# </div>

# %% [markdown]
# # Step 2: Data analysis

# %% [markdown]
# # 2.1 Investigate the proportions of the various types of establishments.

# %%
rest_type = rest.groupby('object_type')['id'].count().reset_index().sort_values(by='id', ascending=False)
rest_type.columns = ['est_type','count']
rest_type
# Out:
#      est_type  count
# 5  Restaurant   7253
# 3   Fast Food   1066
# 2        Cafe    435
# 4       Pizza    319
# 1         Bar    292
# 0      Bakery    283

# %%
fig, ax = plt.subplots(figsize=(15, 15))
ax.pie(rest_type['count'], labels=rest_type['est_type'],autopct='%.1f%%')
ax.set_title('Proportions of the various types of establishments')
plt.legend()
plt.tight_layout()

# %%
plt.savefig('plot_name.png', dpi=300, transparent=True, bbox_inches = "tight")

# %% [markdown]
# over 75% are restraunts!
# Fast food reaches 11% which is respectfull since all other types are under 5%
# Cafe's are 4.5% of the market and bakery's 2.9%.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# 👍 Well done! Nice plot and correct results. Restaurants are the most popular type of catering establishment in LA. You have mastered pie-charts.
# </div>

# %% [markdown]
# # 2.2 Investigate the proportions of chain and nonchain establishments.

# %%
chain_non = rest.groupby('chain')['object_name'].count().reset_index()
chain_non.columns = ['chain','count']

chain_non
# Out:
#    chain  count
# 0  False   5972
# 1   True   3676

# %%
fig, ax = plt.subplots(figsize=(15, 15))
ax.pie(chain_non['count'], labels=chain_non['chain'],autopct='%.1f%%')
ax.set_title('Proportions of chain and nonchain establishments.')
plt.legend()
plt.tight_layout()

# %% [markdown]
# Almost 62% are nonchain establishments good for us to know.
# 38% of the establishments belongs to chains.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# 👍 Well done! The results are correct. Most types are non-chain.
# </div>

# %% [markdown]
# # 2.3 Which type of establishment is typically a chain?

# %%
rest['object_name'].value_counts().head(10)
# Out:
# THE COFFEE BEAN & TEA LEAF    47
# SUBWAY                        31
# DOMINO'S PIZZA                15
# WABA GRILL                    14
# KENTUCKY FRIED CHICKEN        14
# MCDONALD'S                    13
# TRIMANA                       13
# YOGURTLAND                    12
# STARBUCKS                     12
# PAPA JOHN'S PIZZA             12
# Name: object_name, dtype: int64

# %%
chains = rest.loc[rest['chain']==True]
chains.head()
# Out:
#        id               object_name                          address  chain  \
# 8   11794                ABC DONUTS  3027 N SAN FERNANDO RD UNIT 103   True
# 10  11796             EL POLLO LOCO               5319 W SUNSET BLVD   True
# 11  11797         POONG NYUN BAKERY        928 S WESTERN AVE STE 109   True
# 12  11798  EMC RESTAURANT GROUP LLC            3500 W 6TH ST STE 101   True
# 14  11800         CUSCATLECA BAKERY            2501 W SUNSET BLVD #A   True
#
#    object_type  number
# 8    Fast Food       1
# 10  Restaurant      38
# 11      Bakery      17
# 12  Restaurant     133
# 14      Bakery      26

# %%
est_type_chain = chains.groupby('object_type')['id'].count().reset_index().sort_values(by='id', ascending=False)
est_type_chain.columns = ['object_type', 'total_est_c']
est_type_chain
# Out:
#   object_type  total_est_c
# 5  Restaurant         2292
# 3   Fast Food          605
# 0      Bakery          283
# 2        Cafe          266
# 4       Pizza          153
# 1         Bar           77

# %%
total_est = rest['object_type'].value_counts().rename_axis('object_type').reset_index(name='total_est')
total_est
# Out:
#   object_type  total_est
# 0  Restaurant       7253
# 1   Fast Food       1066
# 2        Cafe        435
# 3       Pizza        319
# 4         Bar        292
# 5      Bakery        283

# %%
chain_d = pd.merge(est_type_chain, total_est, how='inner', on='object_type')
chain_d
# Out:
#   object_type  total_est_c  total_est
# 0  Restaurant         2292       7253
# 1   Fast Food          605       1066
# 2      Bakery          283        283
# 3        Cafe          266        435
# 4       Pizza          153        319
# 5         Bar           77        292

# %%
chain_d['ratio'] = chain_d['total_est_c'] / chain_d['total_est'] * 100
chain_d.sort_values(by='ratio', ascending=False).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_e27a6_row0_col1{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_e27a6_row0_col2,#T_e27a6_row5_col1,#T_e27a6_row5_col2,#T_e27a6_row5_col3{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_e27a6_row0_col3,#T_e27a6_row4_col1,#T_e27a6_row4_col2{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e27a6_row1_col1{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_e27a6_row1_col2{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_e27a6_row1_col3{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_e27a6_row2_col1{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_e27a6_row2_col2{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_e27a6_row2_col3{
# ...

# %%
sns.set(rc = {'figure.figsize':(15,10)})
ax=sns.countplot(data=rest, x='object_type', hue='chain').set(title='Establishments chain/nonchain distribution')

# %% [markdown]
# all bakery's belongs to chains 100%.
# Fast food (61.1%) and cafe's (56.7%) are most lilkely belongs to chains.
# Bar's and restaurant's are usually owned to private owners.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# 👍 The results are correct.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment v.1</b>
#
# 📝 Please do not leave results without interim conclusions or brief interpretations.
#
# </div>

# %% [markdown]
# # 2.4 What characterizes chains: many establishments with a small number of seats or a few establishments with a lot of seats?

# %%
chain_seat_num = rest[rest['chain'] == True]['number']
chain_seat_num.head(10)
# Out:
# 8       1
# 10     38
# 11     17
# 12    133
# 14     26
# 15     21
# 24     43
# 27     80
# 29     15
# 31    118
# Name: number, dtype: int64

# %%
chain_seat_num.agg('mode')
chain_seat_num.describe()
# Out:
# count    3676.000000
# mean       39.694233
# std        43.437212
# min         1.000000
# 25%        13.000000
# 50%        25.000000
# 75%        44.000000
# max       229.000000
# Name: number, dtype: float64

# %%
print("Less than or Equal to 49:",
      chain_seat_num[chain_seat_num <= 49].sort_values().tail(10).values)

print("Greater than 49:",
      chain_seat_num[chain_seat_num > 49].sort_values().head(10).values)
# Out:
# Less than or Equal to 49: [49 49 49 49 49 49 49 49 49 49]
# Greater than 49: [61 61 61 62 62 62 62 62 62 62]

# %%
rest['seat'] = rest['number'].apply(
    lambda x: 'few' if x < 50 else 'many')
rest['seat'].head()
# Out:
# 0    few
# 1    few
# 2    few
# 3    few
# 4    few
# Name: seat, dtype: object

# %%
fig, ax = plt.subplots(figsize=(13,6), facecolor='white')
ax.set_facecolor("xkcd:white")
plt.hist(chain_seat_num, alpha=.6, bins=50)

#shading and median

plt.axvline(chain_seat_num.median(), color='gray', linewidth=.9)


#annotate, despine, and grid
plt.annotate("Median: " + str(int(chain_seat_num.median())),
             xy=(25, 350),
             xytext=(40, 355),
             color='darkslategray',
             arrowprops=dict(arrowstyle="fancy"))
sns.despine()
plt.grid(False, axis='x')

#labels
plt.title("LA Chain Establishments: Distribution of Seats",
          fontsize=21,
          x=.28,
          pad=20,
          fontweight='bold')
plt.xlabel('Number Of Seats', labelpad=15, fontsize=18)
plt.ylabel('Count', labelpad=15, fontsize=18)

plt.show()

# %%
rest[rest['chain'] == True]['seat'].value_counts(normalize=True)
# Out:
# few     0.825082
# many    0.174918
# Name: seat, dtype: float64

# %%
#fig = px.histogram(rest, x='number', color = 'chain',  title="Number of seats chain/nonchain distribution ")
#fig.show()

# %% [markdown]
# We can see by the histogram that in general most establisments have small number of seats less then 50. Non chain are the majority in this part but it's the majority also in general.
#
# There is non establisments contains 50-60 seats at all it may not be profitable to open an establishment with such a seating capacity.
#
# When looking at establisments with over 60 seats the gap between cahin and non chain establisments narows and above 150 seats it narows even more.
#
# What characterizes chains is many establishments with a small number of seats. make sense based on what we saw earlier that bakeries, cafes and fast food establishments usually belong to chains and these are places that will usually have fewer seats.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.2</b>
#
# 👍 Thank you for your additional job with the plot here. Now we can study the data only for chain. Also, it is great, that you have shown the median values. You have mastered the `plt.annotate`!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment v.1</b>
#
# 📝 In general, the results are correct. However, please note that in this part it was necessary to look at data only for chains. But, since there is a legend on the chart, and the chart itself is interactive, the task is accepted. However, the type of stacked chart can be misleading in this case.
#
# </div>

# %% [markdown]
# # 2.5 Determine the average number of seats for each type of restaurant. On average, which type of restaurant has the greatest number of seats? Plot graphs.

# %%
avg_seat = rest.groupby(['object_type'])['number'].mean().reset_index().sort_values(by='number', ascending=False)
avg_seat
# Out:
#   object_type     number
# 5  Restaurant  48.048807
# 1         Bar  44.767123
# 3   Fast Food  31.837711
# 4       Pizza  28.545455
# 2        Cafe  25.000000
# 0      Bakery  21.773852

# %%
f, ax = plt.subplots(figsize= (20, 10))
plt.title("Avearge number of seats by establishment type" , fontsize = 16 )
ax=sns.barplot(x="object_type", y="number", data=avg_seat)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                xy=(p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', 
                va = 'center', 
                xytext = (0, 8), 
                textcoords = 'offset points')

# %% [markdown]
# Restaurant's are clearly the eastablisments with greatest number of seats with 48 seats on average followed by bar's with 45. probably people like to be with more company at those places and also seats for a while.
#
# Bakery's has the least number of seats on average with 22 cafe's are a bit above with 25 and pizza with 29. all are establisments that typically constitute a place for a more intimate pastime or simply for takeaway.

# %%
ax = sns.boxplot(x='number', y ='object_type', hue = 'chain',showfliers=False, data = rest)
plt.title( 'Avearge number of seats by establishment type' , fontsize = 18 )
plt.show()

# %% [markdown]
# Chains will have more seats than non ones if we talking about cafe's and fast food establishments fast food has much wider outliers if we talking about chains make sense because chains set up a lot of places and it is easier for them to open larger places.
#
# Non chain bar's will much more seats usually than bars belonging to chains.
#
# In restaurant's field it's a close match with a bit higher average to nonchain restaurant

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# 👍 Well done! Good analysis here! It's great that you looked at the overall data and plotted the box plots. Also, please note, that sometimes it is useful to look at data with anomalies. For example, if we set the `showfliers` parameter as `True` we could see that some of the bakeries or bars have number of seats more than 200.
# </div>

# %% [markdown]
# # 2.6 Put the data on street names from the address column in a separate column.

# %%
street_example=rest.iloc[0]['address']
street_example
# Out:
# '3708 N EAGLE ROCK BLVD'

# %%
usaddress.parse(street_example)
# Out:
# [('3708', 'AddressNumber'),
#  ('N', 'StreetNamePreDirectional'),
#  ('EAGLE', 'StreetName'),
#  ('ROCK', 'StreetName'),
#  ('BLVD', 'StreetNamePostType')]

# %%
raw_address=usaddress.parse(street_example)
raw_address
# Out:
# [('3708', 'AddressNumber'),
#  ('N', 'StreetNamePreDirectional'),
#  ('EAGLE', 'StreetName'),
#  ('ROCK', 'StreetName'),
#  ('BLVD', 'StreetNamePostType')]

# %%
dict_address={}
for i in raw_address:
    dict_address.update({i[1]:i[0]})
dict_address
# Out:
# {'AddressNumber': '3708',
#  'StreetNamePreDirectional': 'N',
#  'StreetName': 'ROCK',
#  'StreetNamePostType': 'BLVD'}

# %%
dict_address['StreetName']+','+dict_address['AddressNumber']
# Out:
# 'ROCK,3708'

# %%
def cleaning_1(raw):
    raw_address=usaddress.parse(raw)
    dict_address={}
    for i in raw_address:
        dict_address.update({i[1]:i[0]})
    clean_adress=dict_address['AddressNumber']+","+str(dict_address['StreetName'])
    return clean_adress

# %%
rest.address.sample(5).apply(cleaning_1)
# Out:
# 1398    600,ALVARADO
# 2009      3084,MOTOR
# 226         3901,6TH
# 5524         531,6TH
# 7085    2897,OLYMPIC
# Name: address, dtype: object

# %%
def cleaning_check(raw):
    raw_address=usaddress.parse(raw)
    dict_address={}
    for i in raw_address:
        dict_address.update({i[1]:i[0]})
        
    if 'StreetName' in dict_address.keys() and 'AddressNumber' in dict_address.keys():
        clean_adress=dict_address['AddressNumber']+","+str(dict_address['StreetName'])
        return clean_adress
    else:
        return 'no street or number'

# %%
rest['clean_street_check']=rest.address.apply(cleaning_check)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment v.1</b>
#
# 📝 In is better to consider the warning here and within the full project.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.2</b>
#
# 👍 Thank you for checking this moment!
# </div>

# %%
rest[rest['clean_street_check']=='no street or number']
# Out:
#          id           object_name                  address  chain object_type  \
# 1888  13674      MAGDALENO DEBBIE            OLVERA ST E17  False  Restaurant
# 3719  15505            LAS ANITAS             OLVERA ST 26  False  Restaurant
# 7003  18789           D.K. DONUTS  1033 1/2 LOS ANGELES ST  False   Fast Food
# 7281  19067         CIELITO LINDO             OLVERA ST 23  False  Restaurant
# 7319  19105        JUANITA'S CAFE             OLVERA ST 20  False  Restaurant
# 7321  19107    KITTY'S SNOW CONES              OLVERA ST 2  False  Restaurant
# 7327  19113        LA NOCHE BUENA             OLVERA ST E8  False  Restaurant
# 7438  19224         LA GOLONDRINA            OLVERA ST W17  False  Restaurant
# 7741  19527  RODOLFO'S RESTAURANT              OLVERA ST 5   True  Restaurant
#
#       number  seat   clean_street_check
# 1888      15   few  no street or number
# 3719      38   few  no street or number
# 7003       8   few  no street or number
# ...

# %%
usaddress.parse(rest.iloc[1888]['address'])
# Out:
# [('OLVERA', 'PlaceName'), ('ST', 'StateName'), ('E17', 'ZipCode')]

# %%
def cleaning_final(raw):
    if raw.startswith('OLVERA'):
        clean_adress='OLVERA,Los Angeles,USA'
    elif raw.startswith('1033 1/2 LOS ANGELES'):
        clean_adress='1033 1/2 LOS ANGELES ST,Los Angeles,USA'
    else:
        raw_address=usaddress.parse(raw)
        dict_address={}
        for i in raw_address:
            dict_address.update({i[1]:i[0]})
        clean_adress=dict_address['AddressNumber']+" "+str(dict_address['StreetName'])+str(', Los Angeles,USA')
    return clean_adress

# %%
rest['clean_street_final']=rest.address.apply(cleaning_final)
rest.sample(10)
# Out:
#          id                   object_name                   address  chain  \
# 3927  15713                   THE VILLAGE     6333 W 3RD ST STE 334  False
# 8812  20598                 POLLITOS DELI            7609 S MAIN ST   True
# 5502  17288     PRIMO'S EXPRESSO AMERICAN       333 S SPRING ST #F3  False
# 8686  20472  JAPANESE AMERICAN NAT. MUSEU  100 N CENTRAL AVE # #110  False
# 4195  15981                    GENESIS #2          1423 W PICO BLVD  False
# 8872  20658                   NEON COFFEE        3206 W SUNSET BLVD  False
# 9401  21187        KRISPY KREME DOUGHNUTS        4034 CRENSHAW BLVD  False
# 6742  18528                          IHOP          12115 W OHIO AVE   True
# 7420  19206      THE CALIFORNIA ENDOWMENT         1000 N ALAMEDA ST  False
# 2434  14220               BLUE COLLAR PUB         361 S FAIRFAX AVE  False
#
#      object_type  number  seat clean_street_check  \
# 3927  Restaurant      18   few           6333,3RD
# ...

# %%
address_list = rest["address"].to_list()
street_list = []
for addr in address_list:
    try:
        data = usaddress.tag(addr)
        if "StreetName" in data[0].keys():
            street_list.append(data[0]["StreetName"])
        else:
            street_list.append("no city/town")
    except:
        if "ASTRONAUT" in addr:
            street_list.append("ASTRONAUT")
        else:
            street_list.append("no street address")

rest["street"] = street_list
rest["street"] = rest["street"].str.title()
rest.head()
# Out:
#       id          object_name                    address  chain object_type  \
# 0  11786  HABITAT COFFEE SHOP     3708 N EAGLE ROCK BLVD  False        Cafe
# 1  11787             REILLY'S        100 WORLD WAY # 120  False  Restaurant
# 2  11788       STREET CHURROS  6801 HOLLYWOOD BLVD # 253  False   Fast Food
# 3  11789    TRINITI ECHO PARK         1814 W SUNSET BLVD  False  Restaurant
# 4  11790               POLLEN         2100 ECHO PARK AVE  False  Restaurant
#
#    number seat clean_street_check               clean_street_final      street
# 0      26  few          3708,ROCK       3708 ROCK, Los Angeles,USA  Eagle Rock
# 1       9  few          100,WORLD       100 WORLD, Los Angeles,USA       World
# 2      20  few     6801,HOLLYWOOD  6801 HOLLYWOOD, Los Angeles,USA   Hollywood
# 3      22  few        1814,SUNSET     1814 SUNSET, Los Angeles,USA      Sunset
# 4      20  few          2100,PARK       2100 PARK, Los Angeles,USA   Echo Park

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# 👏 The perfect using the usaddress lybrary here! In this case, we could also parse the full street name, using all data with StreetName key:
# </div>

# %%
street_name = ''
for i in usaddress.parse('2100 ECHO PARK AVE'):
    if 'StreetName' == i[1]:
        street_name += i[0] + ' '
street_name.rstrip()
# Out:
# 'ECHO PARK'

# %% [markdown]
# # 2.7 Plot a graph of the top ten streets by number of restaurants.

# %%
rest_p_s = rest.groupby(['street'])['id'].count().reset_index()
rest_p_s.columns = ['street','total_est' ]
top_10_s = rest_p_s.sort_values('total_est', ascending = False).head(10)
top_10_s
# Out:
#            street  total_est
# 419        Sunset        405
# 469      Wilshire        398
# 359          Pico        371
# 459       Western        369
# 176      Figueroa        334
# 341       Olympic        309
# 443       Vermont        288
# 389  Santa Monica        264
# 23            3Rd        262
# 221     Hollywood        254

# %%
f, ax = plt.subplots(figsize= (20, 10))
plt.title("Top 10 streets by number of restaurants" , fontsize = 16 )
ax=sns.barplot(x="street", y="total_est", data=top_10_s)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                xy=(p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', 
                va = 'center', 
                xytext = (0, 8), 
                textcoords = 'offset points')
plt.show()

# %% [markdown]
# Sunset street is the one with most establishments around it in LA with 405!
#
# Wilshire street comes second with 398 establishments.
#
# Holywood street is last among top 10 with 254.
#
# In general there are 6 streets in LA with over 300 restaurants it has to be streets with a lot of crowd traffic in order for such large quantity of establishments in one street to exist it will be recommended to open a buisness

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# ⭐ Good job here! The results are correct!
# </div>

# %% [markdown]
# # 2.8 Find the number of streets that only have one restaurant.

# %%
rest_p_s_1 = rest_p_s.query('total_est==1')
rest_p_s_1.shape[0]
# Out:
# 192

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# 👍 Correct!
#
# </div>

# %% [markdown]
# 2.9 For streets with a lot of restaurants, look at the distribution of the number of seats. What trends can you see?

# %%
rest_p_s['total_est'].mean()
# Out:
# 20.016597510373444

# %%
rest_p_s['total_est'].median()
# Out:
# 2.0

# %%
top_streets = top_10_s['street'].tolist()
top_streets
# Out:
# ['Sunset',
#  'Wilshire',
#  'Pico',
#  'Western',
#  'Figueroa',
#  'Olympic',
#  'Vermont',
#  'Santa Monica',
#  '3Rd',
#  'Hollywood']

# %%
top10 = rest.query('street == @top_streets')
top10
# Out:
#          id                object_name                         address  chain  \
# 2     11788             STREET CHURROS       6801 HOLLYWOOD BLVD # 253  False
# 3     11789          TRINITI ECHO PARK              1814 W SUNSET BLVD  False
# 10    11796              EL POLLO LOCO              5319 W SUNSET BLVD   True
# 11    11797          POONG NYUN BAKERY       928 S WESTERN AVE STE 109   True
# 14    11800          CUSCATLECA BAKERY           2501 W SUNSET BLVD #A   True
# ...     ...                        ...                             ...    ...
# 9634  21420                 MILD SAUCE       8500 W OLYMPIC BLVD STE B  False
# 9635  21421  THE TEA & COFFEE EXCHANGE       6801 HOLLYWOOD BLVD # 120  False
# 9639  21425                 MCDONALD'S              1800 S WESTERN AVE   True
# 9645  21431                 SAINT MARC  10250 SANTA MONICA BLVD # 1025  False
# 9648  21434                JUICY WINGZ             6741 HOLLYWOOD BLVD   True
#
# ...

# %%
top10_seats_avg = top10.groupby('street', as_index = False).agg({'number':'mean'})
top10_seats_avg
# Out:
#          street     number
# 0           3Rd  40.553435
# 1      Figueroa  45.050898
# 2     Hollywood  56.842520
# 3       Olympic  49.339806
# 4          Pico  40.544474
# 5  Santa Monica  35.045455
# 6        Sunset  47.903704
# 7       Vermont  45.371528
# 8       Western  41.344173
# 9      Wilshire  52.655779

# %%
rest['number'].mean()
# Out:
# 43.70356550580431

# %%
rest['number'].median()
# Out:
# 27.0

# %%
ax = sns.boxplot(x = 'number', y = 'street', data = top10)
plt.title( 'Seats distribution in streets crowded with restuarunts' , fontsize = 18 )
plt.show()

# %%
sns.set(rc={"figure.figsize": (25,12)})
ax = sns.histplot(top10['number'])
ax.set_title('Seats distribution in streets crowded with restuarunts', fontsize = 20)
ax.set_xlabel('Number of seats')
ax.set_ylabel('Streets Density')


for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                xy=(p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', 
                va = 'center', 
                xytext = (0, 10), 
                textcoords = 'offset points')
plt.show()

# %% [markdown]
# Most of establishments in the crowded streets are smaller and contains 0-50 seats.
#
# Much less establishments contains 50 seats and more make sense with streets so full of restaurants t0 open places with less seating.
#
# Wilshire street has the largest median indicates a larger amount of restaurants with more seating.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Reviewer's comment v.1</b>
#
# ✍ Please provide conclusions in this part.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.2</b>
#
# 👍 Thanks!
#
# </div>

# %% [markdown]
# # Conclusion and recommendations

# %% [markdown]
# If there is a thought of developing a chain there is a preference for opening a cafe or bakery, since the vast majority of them belong to the chains. Probably also related to operating costs because when there are multiple branches it lowers costs for certain products that are consumed more in these establishments so a robot cafe chain can be a good idea. It is also a simpler option for working with robots and lighter products and less stock of details as opposed to a restaurant, or messing with drunk people as opposed to bars.
#
# Establishments that are cafes and bakeries usually contain less seating (23-25). But when they belong to a particular chain there are slightly more seats than when they are not associated with a chain i would recommend to open a place with up to 30 seats maybe the robots will attract a little more customers.
#
# In terms of location, there is a preference for restaurant stock streets, probably because there will be greater traffic and the possibility of more customers. Not necessarily to the streets with the most restaurants but something in the middle such as Santa Monica where the average number of chairs is also suitable for the establishment that is recommended to open.
#
# There is also the possibility of opening on streets where there is one restaurant and there will probably be less competition but one should check that the streets are close enough to major places from there already the robot attraction will attract them.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# 👍 Well done! Your conclusions are complete and contain excellent recommendations for opening a cafe. Indeed, a cafe or a bakery looks promising given the ideas of robotization.
#
# </div>

# %% [markdown]
# # Step 3. Presentation

# %% [markdown]
# Hi, I'm not sure everything is OK. I made one, but I berfere, if you please, to send it after the  revinew, to make fixes if needed, and to see your notes and  recommendations.

# %%
#https://drive.google.com/file/d/1OaSti-TXF6mlD84NX23WQcxSa1uUI8fK/view?usp=sharing

# %% [markdown]
# the new presentation link:

# %% [markdown]
# https://drive.google.com/file/d/1wCzYYfmlEYyRtNtoEgf_xTElMH5cBMxO/view?usp=sharing

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.2</b>
#
# 👍 It is good that the presentation has a single design style and contains a table of contents. It's great that the graphics have a detailed description, and at the end there is a slide with a conclusion. The results are in line with the project.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment v.2</b>
#
# However, I have some recommendation for the slide's design. Now many charts are small, making it difficult to read the legend or draw conclusions from them.
#
# It is necessary to change the size of graphs and/or fonts. Also, please find below some examples for reorganizing slides.
#
# ---
#
# Pie chart captions need improvement - percentages are not visible now. To do this, you should change the size of the graph in the notebook itself to make the signatures larger or change the font.
#
#
# </div>

# %% [markdown]
# ![2022-11-14_09-44-37.png](attachment:2022-11-14_09-44-37.png)

# %%
# the reviewer's cell: changing plot-size and text-font size
fig, ax = plt.subplots(figsize=(10, 10))
ax.pie(rest_type['count'], labels=rest_type['est_type'], autopct='%.1f%%', textprops={'fontsize': 16})
ax.set_title('Proportions of the various types of establishments').set_fontsize(18)
plt.legend()
plt.tight_layout()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment v.2</b>
#
# Also, some slides should be redesigned: increase the size of the graph and change the position of the text. Please see examples below.
# </div>

# %% [markdown]
# ![2022-11-14_09-50-02.png](attachment:2022-11-14_09-50-02.png)

# %% [markdown]
# ![2022-11-14_09-52-26.png](attachment:2022-11-14_09-52-26.png)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.2</b>
#
# 👍 Also, we could save the image in good quality using this way (for Matplotlib plots):
#
# `plt.savefig('plot_name.png', dpi=300, transparent=True, bbox_inches = "tight")  `
#
# We could use different images types (png, pdf, jpg ...) and change the plot resolution (dpi). Also, we could make plots transparent.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student's comment v.1</b>
#     I don't know how to thank you for this nice knowledge especially the code how to download images of the plots.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.3</b>
#
# 👍 I am glad to help! Thank you for considering this point!
#
# </div>
